# %% [markdown]
# # Video Game Recommender Project

# %% [markdown]
# ## Part 2: Cleaning the Data for Modeling

# %%
import pandas as pd
import re
import requests

# %%
df = pd.read_csv('./Data/games.csv', low_memory=False)
df
# Out:
#         Unnamed: 0      id                                       age_ratings  \
# 0                0  131913                                          [101730]
# 1                1   88308                                               NaN
# 2                2   63308                                           [14739]
# 3                3   95080                                               NaN
# 4                4  104748                                               NaN
# ...            ...     ...                                               ...
# 274115     2738495  270311  [155339, 156812, 156813, 156814, 156815, 156816]
# 274116     2738496   26778                             [12738, 12739, 74252]
# 274117     2738497  287107                                          [167130]
# 274118     2738498  172430                     [46359, 55966, 95862, 118055]
# 274119     2738499  144153                     [56026, 85840, 91948, 125050]
#
#                      alternative_names  category     cover  created_at  \
# 0                [40085, 40086, 40087]         0  267633.0  1584788069
# 1                                  NaN         0   64849.0  1519237439
# 2                                  NaN         0   78658.0  1505087910
# 3                                  NaN         0       NaN  1521818623
# 4                                  NaN         0       NaN  1530519587
# ...                                ...       ...       ...         ...
# 274115                             NaN         0  338712.0  1696471845
# 274116         [23222, 103500, 103531]         0  345907.0  1484338599
# 274117                             NaN         0       NaN  1708046589
# 274118                        [102314]         8  180918.0  1632435987
# 274119  [66217, 66713, 103492, 103527]         0  161784.0  1614698344
#
#                                            external_games  first_release_date  \
# 0                                               [1977891]        1.474416e+09
# 1                                       [243459, 1960113]        1.478650e+09
# 2                                [12596, 118080, 1185144]        1.372810e+09
# 3                                               [1989881]                 NaN
# 4                                      [1155919, 1972586]                 NaN
# ...                                                   ...                 ...
# 274115  [2749772, 2749823, 2749915, 2749948, 2749957, ...        1.697674e+09
# 274116  [46568, 148728, 215876, 246558, 402671, 459935...        5.311872e+08
# 274117                        [2888238, 2888279, 2888301]        1.707782e+09
# 274118  [2124213, 2124220, 2124674, 2135085, 2160840, ...        1.632355e+09
# 274119  [1998774, 2042130, 2071888, 2071912, 2071932, ...        1.629763e+09
#
#        game_modes  ... aggregated_rating_count     ports dlcs   remakes  \
# 0             [1]  ...                     NaN       NaN  NaN       NaN
# 1             NaN  ...                     NaN       NaN  NaN       NaN
# 2          [2, 3]  ...                     NaN       NaN  NaN       NaN
# 3             NaN  ...                     NaN       NaN  NaN       NaN
# 4             NaN  ...                     NaN       NaN  NaN       NaN
# ...           ...  ...                     ...       ...  ...       ...
# 274115        [1]  ...                     NaN       NaN  NaN       NaN
# 274116        [1]  ...                     NaN  [109597]  NaN  [134561]
# 274117        NaN  ...                     NaN       NaN  NaN       NaN
# 274118        [1]  ...                     2.0       NaN  NaN       NaN
# 274119  [1, 2, 3]  ...                    12.0       NaN  NaN       NaN
#
#        franchise expansions standalone_expansions forks remasters  \
# 0            NaN        NaN                   NaN   NaN       NaN
# 1            NaN        NaN                   NaN   NaN       NaN
# 2            NaN        NaN                   NaN   NaN       NaN
# 3            NaN        NaN                   NaN   NaN       NaN
# 4            NaN        NaN                   NaN   NaN       NaN
# ...          ...        ...                   ...   ...       ...
# 274115       NaN        NaN                   NaN   NaN       NaN
# 274116       NaN        NaN                   NaN   NaN       NaN
# 274117       NaN        NaN                   NaN   NaN       NaN
# 274118       NaN        NaN                   NaN   NaN       NaN
# 274119       NaN   [204435]                   NaN   NaN       NaN
#
#        expanded_games
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 274115            NaN
# 274116            NaN
# 274117            NaN
# 274118            NaN
# 274119            NaN
#
# [274120 rows x 59 columns]

# %% [markdown]
# The first thing I notice about the data is that there are rows for dlc, remakes, expansions, remasters, etc... These rows contain an ID number, which means that those ids hold their own row in the dataframe. I do not want my recommender to recommend add-ons to games, so we have to drop the rows in which these ids appear.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'age_ratings', 'alternative_names', 'category',
#        'cover', 'created_at', 'external_games', 'first_release_date',
#        'game_modes', 'genres', 'involved_companies', 'keywords', 'name',
#        'platforms', 'player_perspectives', 'release_dates', 'screenshots',
#        'similar_games', 'slug', 'storyline', 'summary', 'tags', 'themes',
#        'updated_at', 'url', 'videos', 'websites', 'checksum',
#        'game_localizations', 'collection', 'multiplayer_modes', 'status',
#        'language_supports', 'collections', 'hypes', 'artworks',
#        'version_parent', 'version_title', 'parent_game', 'bundles',
#        'franchises', 'follows', 'rating', 'rating_count', 'total_rating',
#        'total_rating_count', 'game_engines', 'aggregated_rating',
#        'aggregated_rating_count', 'ports', 'dlcs', 'remakes', 'franchise',
#        'expansions', 'standalone_expansions', 'forks', 'remasters',
#        'expanded_games'],
#       dtype='object')

# %%
def extract_ids(string):
    return [int(x) for x in re.findall(r'\d+', string)] 
#extracts the digits, in this case the ids, in the df
#('\d+') looks for 1 or more digits in the string provided
#return [int(x) for x... returns it as an int

# %%
non_null_values_dlcs = df['dlcs'].dropna()
unique_values_dlcs = non_null_values_dlcs.unique().tolist()
dlcs_ids = [id_ for sublist in map(extract_ids, unique_values_dlcs) for id_ in sublist]
# get all non nan values, so we only have games that do have dlcs, make a list of the ids that are dlcs
# so then we can remove them from the dataframe
# map() executes the process for each item that it is given, in this case, extract id in the list created
# by the variables in the dlcs column, and turn them into int so we can identify them in the id column.

# %%
non_null_values_remakes = df['remakes'].dropna()
unique_values_remakes = non_null_values_remakes.unique().tolist()
remakes_ids = [id_ for sublist in map(extract_ids, unique_values_remakes) for id_ in sublist]

# %%
non_null_values_expansions = df['expansions'].dropna()
unique_values_expansions = non_null_values_expansions.unique().tolist()
expansions_ids = [id_ for sublist in map(extract_ids, unique_values_expansions) for id_ in sublist]

# %%
non_null_values_standalone_expansions = df['standalone_expansions'].dropna()
unique_values_standalone_expansions = non_null_values_standalone_expansions.unique().tolist()
standalone_expansions_ids = [id_ for sublist in map(extract_ids, unique_values_standalone_expansions) for id_ in sublist]

# %%
non_null_values_remasters = df['remasters'].dropna()
unique_values_remasters = non_null_values_remasters.unique().tolist()
remasters_ids = [id_ for sublist in map(extract_ids, unique_values_remasters) for id_ in sublist]

# %%
non_null_values_ports = df['ports'].dropna()
unique_values_ports = non_null_values_ports.unique().tolist()
ports_ids = [id_ for sublist in map(extract_ids, unique_values_ports) for id_ in sublist]

# %%
non_null_values_expanded_games = df['expanded_games'].dropna()
unique_values_expanded_games = non_null_values_expanded_games.unique().tolist()
expanded_games_ids = [id_ for sublist in map(extract_ids, unique_values_expanded_games) for id_ in sublist]

# %%
all_ids = dlcs_ids + remakes_ids + expansions_ids + standalone_expansions_ids + remasters_ids + ports_ids + expanded_games_ids
df = df[~df['id'].isin(all_ids)] 
df

# finally we have all the ids we need to drop so we transform the dataframe
# ~ makes it so we have the whole dataframe except for all_ids, negates all_ids
# Out:
#         Unnamed: 0      id                                       age_ratings  \
# 0                0  131913                                          [101730]
# 1                1   88308                                               NaN
# 2                2   63308                                           [14739]
# 3                3   95080                                               NaN
# 4                4  104748                                               NaN
# ...            ...     ...                                               ...
# 274114     2738494  148382                    [58294, 95857, 110147, 118294]
# 274115     2738495  270311  [155339, 156812, 156813, 156814, 156815, 156816]
# 274116     2738496   26778                             [12738, 12739, 74252]
# 274117     2738497  287107                                          [167130]
# 274119     2738499  144153                     [56026, 85840, 91948, 125050]
#
#                      alternative_names  category     cover  created_at  \
# 0                [40085, 40086, 40087]         0  267633.0  1584788069
# 1                                  NaN         0   64849.0  1519237439
# 2                                  NaN         0   78658.0  1505087910
# 3                                  NaN         0       NaN  1521818623
# 4                                  NaN         0       NaN  1530519587
# ...                                ...       ...       ...         ...
# 274114                        [108185]         0  213777.0  1621638326
# 274115                             NaN         0  338712.0  1696471845
# 274116         [23222, 103500, 103531]         0  345907.0  1484338599
# 274117                             NaN         0       NaN  1708046589
# 274119  [66217, 66713, 103492, 103527]         0  161784.0  1614698344
#
#                                            external_games  first_release_date  \
# 0                                               [1977891]        1.474416e+09
# 1                                       [243459, 1960113]        1.478650e+09
# 2                                [12596, 118080, 1185144]        1.372810e+09
# 3                                               [1989881]                 NaN
# 4                                      [1155919, 1972586]                 NaN
# ...                                                   ...                 ...
# 274114  [2056735, 2242321, 2242372, 2581765, 2583302, ...        1.645402e+09
# 274115  [2749772, 2749823, 2749915, 2749948, 2749957, ...        1.697674e+09
# 274116  [46568, 148728, 215876, 246558, 402671, 459935...        5.311872e+08
# 274117                        [2888238, 2888279, 2888301]        1.707782e+09
# 274119  [1998774, 2042130, 2071888, 2071912, 2071932, ...        1.629763e+09
#
#        game_modes  ... aggregated_rating_count     ports  \
# 0             [1]  ...                     NaN       NaN
# 1             NaN  ...                     NaN       NaN
# 2          [2, 3]  ...                     NaN       NaN
# 3             NaN  ...                     NaN       NaN
# 4             NaN  ...                     NaN       NaN
# ...           ...  ...                     ...       ...
# 274114        [1]  ...                     NaN       NaN
# 274115        [1]  ...                     NaN       NaN
# 274116        [1]  ...                     NaN  [109597]
# 274117        NaN  ...                     NaN       NaN
# 274119  [1, 2, 3]  ...                    12.0       NaN
#
#                                     dlcs   remakes franchise expansions  \
# 0                                    NaN       NaN       NaN        NaN
# 1                                    NaN       NaN       NaN        NaN
# 2                                    NaN       NaN       NaN        NaN
# 3                                    NaN       NaN       NaN        NaN
# 4                                    NaN       NaN       NaN        NaN
# ...                                  ...       ...       ...        ...
# 274114  [201018, 231236, 231241, 231242]       NaN       NaN        NaN
# 274115                               NaN       NaN       NaN        NaN
# 274116                               NaN  [134561]       NaN        NaN
# 274117                               NaN       NaN       NaN        NaN
# 274119                               NaN       NaN       NaN   [204435]
#
#        standalone_expansions forks remasters expanded_games
# 0                        NaN   NaN       NaN            NaN
# 1                        NaN   NaN       NaN            NaN
# 2                        NaN   NaN       NaN            NaN
# 3                        NaN   NaN       NaN            NaN
# 4                        NaN   NaN       NaN            NaN
# ...                      ...   ...       ...            ...
# 274114                   NaN   NaN       NaN            NaN
# 274115                   NaN   NaN       NaN            NaN
# 274116                   NaN   NaN       NaN            NaN
# 274117                   NaN   NaN       NaN            NaN
# 274119                   NaN   NaN       NaN            NaN
#
# [249838 rows x 59 columns]

# %% [markdown]
# Now, we can select the features we want to model with. The most important features are summary, platforms, genres and game modes. I could have used more features, but that came with caveats. For each feature I kept, it significantly decreased the total of my data set. This is because there was data with NaN values, and there was no correct way to deal with them other than to drop the rows that had NaN values. I can not put 0's or the average of the age rating because then it would not be an accurate or relative representation of the specific game. A lot of games did not have age ratings, so if I wanted to model with this feature, i would have had to drop over 50 000 games. It was like this with a lot of features, and these features I kept were the happy medium. (I also enjoy small indie games, so I wanted to keep a large dataset so that my recommender can recommend even lesser budget/indie games. If I dropped more games with missing values, than those games would have been weeded out of the data.) So finally we end up with a dataset of just over 100 000!

# %%
df = df[['name', 'summary', 'platforms', 'genres', 'game_modes', 'url']]
df
# Out:
#                                                      name  \
# 0                                  Maji Kyun! Renaissance
# 1                         Hey Duggee: The Big Outdoor App
# 2                                         Soldier Front 2
# 3                                                   Dotra
# 4                      Space station - build your own ISS
# ...                                                   ...
# 274114                                         Sol Cresta
# 274115                                    Animal Hospital
# 274116                         Alex Kidd in Miracle World
# 274117  Is It Wrong to Try to Pick Up Girls in a Dunge...
# 274119                             Aliens: Fireteam Elite
#
#                                                   summary  \
# 0       A cross media collaboration project between Su...
# 1       Welcome to the Big Outdoors, Squirrels! Introd...
# 2       A free-to-play multiplayer FPS currently in cl...
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 274114  DOCK, SPLIT, and FORM UP!\nPilot three ships a...
# 274115  Young animal lovers are warmly invited to come...
# 274116  Journey through the planet Aries to the beauti...
# 274117                                                NaN
# 274119  Set in the iconic Alien universe, Aliens: Fire...
#
#                          platforms           genres game_modes  \
# 0                             [46]             [34]        [1]
# 1                             [39]              NaN        NaN
# 2                              [6]              [5]     [2, 3]
# 3                              NaN              NaN        NaN
# 4                              NaN              NaN        NaN
# ...                            ...              ...        ...
# 274114                [6, 48, 130]  [5, 31, 32, 33]        [1]
# 274115     [48, 49, 130, 167, 169]             [13]        [1]
# 274116                  [5, 9, 64]      [8, 25, 31]        [1]
# 274117                   [48, 167]             [12]        NaN
# 274119  [6, 48, 49, 130, 167, 169]      [5, 12, 31]  [1, 2, 3]
#
#                                                       url
# 0        https://www.igdb.com/games/maji-kyun-renaissance
# 1       https://www.igdb.com/games/hey-duggee-the-big-...
# 2              https://www.igdb.com/games/soldier-front-2
# 3                        https://www.igdb.com/games/dotra
# 4       https://www.igdb.com/games/space-station-build...
# ...                                                   ...
# 274114              https://www.igdb.com/games/sol-cresta
# 274115      https://www.igdb.com/games/animal-hospital--1
# 274116  https://www.igdb.com/games/alex-kidd-in-miracl...
# 274117  https://www.igdb.com/games/is-it-wrong-to-try-...
# 274119   https://www.igdb.com/games/aliens-fireteam-elite
#
# [249838 rows x 6 columns]

# %%
df = df.dropna()
df
# Out:
#                                     name  \
# 0                 Maji Kyun! Renaissance
# 2                        Soldier Front 2
# 5                   Bubble Whirl Shooter
# 9       Blood Bowl 3: Black Orcs Edition
# 10                            Pet Puzzle
# ...                                  ...
# 274113      .T.E.S.T: Expected Behaviour
# 274114                        Sol Cresta
# 274115                   Animal Hospital
# 274116        Alex Kidd in Miracle World
# 274119            Aliens: Fireteam Elite
#
#                                                   summary  \
# 0       A cross media collaboration project between Su...
# 2       A free-to-play multiplayer FPS currently in cl...
# 5       Shoot bubbles and match colors to pop your way...
# 9       Fashion is not exactly a priority for Black Or...
# 10      Pet Puzzle is a relaxing and leisurely three-i...
# ...                                                   ...
# 274113  .T.E.S.T: Expected Behavior is a 3D first-pers...
# 274114  DOCK, SPLIT, and FORM UP!\nPilot three ships a...
# 274115  Young animal lovers are warmly invited to come...
# 274116  Journey through the planet Aries to the beauti...
# 274119  Set in the iconic Alien universe, Aliens: Fire...
#
#                          platforms           genres game_modes  \
# 0                             [46]             [34]        [1]
# 2                              [6]              [5]     [2, 3]
# 5                         [34, 39]          [9, 33]        [1]
# 9                        [49, 169]             [15]     [1, 2]
# 10                             [6]             [13]        [1]
# ...                            ...              ...        ...
# 274113        [6, 14, 48, 49, 130]  [9, 13, 31, 32]        [1]
# 274114                [6, 48, 130]  [5, 31, 32, 33]        [1]
# 274115     [48, 49, 130, 167, 169]             [13]        [1]
# 274116                  [5, 9, 64]      [8, 25, 31]        [1]
# 274119  [6, 48, 49, 130, 167, 169]      [5, 12, 31]  [1, 2, 3]
#
#                                                       url
# 0        https://www.igdb.com/games/maji-kyun-renaissance
# 2              https://www.igdb.com/games/soldier-front-2
# 5         https://www.igdb.com/games/bubble-whirl-shooter
# 9       https://www.igdb.com/games/blood-bowl-3-black-...
# 10                  https://www.igdb.com/games/pet-puzzle
# ...                                                   ...
# 274113  https://www.igdb.com/games/dot-t-e-dot-s-t-exp...
# 274114              https://www.igdb.com/games/sol-cresta
# 274115      https://www.igdb.com/games/animal-hospital--1
# 274116  https://www.igdb.com/games/alex-kidd-in-miracl...
# 274119   https://www.igdb.com/games/aliens-fireteam-elite
#
# [111595 rows x 6 columns]

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                     name  \
# 0                 Maji Kyun! Renaissance
# 1                        Soldier Front 2
# 2                   Bubble Whirl Shooter
# 3       Blood Bowl 3: Black Orcs Edition
# 4                             Pet Puzzle
# ...                                  ...
# 111590      .T.E.S.T: Expected Behaviour
# 111591                        Sol Cresta
# 111592                   Animal Hospital
# 111593        Alex Kidd in Miracle World
# 111594            Aliens: Fireteam Elite
#
#                                                   summary  \
# 0       A cross media collaboration project between Su...
# 1       A free-to-play multiplayer FPS currently in cl...
# 2       Shoot bubbles and match colors to pop your way...
# 3       Fashion is not exactly a priority for Black Or...
# 4       Pet Puzzle is a relaxing and leisurely three-i...
# ...                                                   ...
# 111590  .T.E.S.T: Expected Behavior is a 3D first-pers...
# 111591  DOCK, SPLIT, and FORM UP!\nPilot three ships a...
# 111592  Young animal lovers are warmly invited to come...
# 111593  Journey through the planet Aries to the beauti...
# 111594  Set in the iconic Alien universe, Aliens: Fire...
#
#                          platforms           genres game_modes  \
# 0                             [46]             [34]        [1]
# 1                              [6]              [5]     [2, 3]
# 2                         [34, 39]          [9, 33]        [1]
# 3                        [49, 169]             [15]     [1, 2]
# 4                              [6]             [13]        [1]
# ...                            ...              ...        ...
# 111590        [6, 14, 48, 49, 130]  [9, 13, 31, 32]        [1]
# 111591                [6, 48, 130]  [5, 31, 32, 33]        [1]
# 111592     [48, 49, 130, 167, 169]             [13]        [1]
# 111593                  [5, 9, 64]      [8, 25, 31]        [1]
# 111594  [6, 48, 49, 130, 167, 169]      [5, 12, 31]  [1, 2, 3]
#
#                                                       url
# 0        https://www.igdb.com/games/maji-kyun-renaissance
# 1              https://www.igdb.com/games/soldier-front-2
# 2         https://www.igdb.com/games/bubble-whirl-shooter
# 3       https://www.igdb.com/games/blood-bowl-3-black-...
# 4                   https://www.igdb.com/games/pet-puzzle
# ...                                                   ...
# 111590  https://www.igdb.com/games/dot-t-e-dot-s-t-exp...
# 111591              https://www.igdb.com/games/sol-cresta
# 111592      https://www.igdb.com/games/animal-hospital--1
# 111593  https://www.igdb.com/games/alex-kidd-in-miracl...
# 111594   https://www.igdb.com/games/aliens-fireteam-elite
#
# [111595 rows x 6 columns]

# %% [markdown]
# So now we have our dataset. As we can see, there are id's in the platforms, genres, and game_modes columns. To get the values associated with those id's, I had to get the data from the API and put it in a dataframe. I ran the same initial code that gave me the all the games, just had to change the url and create new values to match the specifications that I needed. Once the data is in a dataframe, I can create a dictionary with the values associated with each id, and transfer the information over to the main dataframe and replace the ids with the names associated with the id number.

# %%
client_id = "8m485qqc89htq84deio57c7tryri4v"
client_secret = "6ci2zwn9i9seth4ldmpwf053hcvoj9"
access_token = 'ok2zlmcqawhs5qsxk3nolcsupe51nl'

# %%
url = "https://api.igdb.com/v4/platforms"

# initialize an empty list to store all games
all_platforms = []

# define initial query parameters
params = {
    "fields": "*",
    "limit": 500,  # adjust as needed
    "offset": 0   # start from the beginning
}

# include access token in the headers for authentication
headers = {
    "Client-ID": client_id,
    "Authorization": f"Bearer {access_token}"
}

# set a cap for the total number of games
cap_platforms = 10000000

# make the GET requests until the cap is reached
while len(all_platforms) < cap_platforms:
    response = requests.get(url, headers=headers, params=params)
    
    # check if the request was successful
    if response.status_code == 200:
        # convert the response to JSON
        platforms_data = response.json()
        
        # add the retrieved games to the list
        all_platforms.extend(platforms_data)
        
        # check if there are more games to fetch
        if len(platforms_data) < 50:
            break  # exit the loop if there are no more games to fetch
        else:
            # increment the offset to fetch the next page of results
            params["offset"] += 50
    else:
        print("Failed to retrieve data:", response.status_code)
        break

all_platforms = all_platforms[:cap_platforms]

# create df from the collected platforms
platforms_df = pd.DataFrame(all_platforms)

platforms_df = platforms_df[['name', 'id']]

# %%
platforms_response = []

# iterate over each row in the DataFrame
for index, row in platforms_df.iterrows():
    # create a dictionary for each platform
    platform_dict = {'id': row['id'], 'name': row['name']}
    # append the dictionary to the list
    platforms_response.append(platform_dict)

platforms_response
# Out:
# [{'id': 123, 'name': 'WonderSwan Color'},
#  {'id': 128, 'name': 'PC Engine SuperGrafx'},
#  {'id': 129, 'name': 'Texas Instruments TI-99'},
#  {'id': 133, 'name': 'Odyssey 2 / Videopac G7000'},
#  {'id': 134, 'name': 'Acorn Electron'},
#  {'id': 135, 'name': 'Hyper Neo Geo 64'},
#  {'id': 136, 'name': 'Neo Geo CD'},
#  {'id': 142, 'name': 'PC-50X Family'},
#  {'id': 144, 'name': 'AY-3-8710'},
#  {'id': 146, 'name': 'AY-3-8605'},
#  {'id': 147, 'name': 'AY-3-8606'},
#  {'id': 148, 'name': 'AY-3-8607'},
#  {'id': 149, 'name': 'PC-9800 Series'},
#  {'id': 6, 'name': 'PC (Microsoft Windows)'},
#  {'id': 8, 'name': 'PlayStation 2'},
#  {'id': 23, 'name': 'Dreamcast'},
#  {'id': 25, 'name': 'Amstrad CPC'},
#  {'id': 35, 'name': 'Sega Game Gear'},
#  {'id': 39, 'name': 'iOS'},
#  {'id': 44, 'name': 'Tapwave Zodiac'},
#  {'id': 50, 'name': '3DO Interactive Multiplayer'},
#  {'id': 62, 'name': 'Atari Jaguar'},
#  {'id': 65, 'name': 'Atari 8-bit'},
#  {'id': 88, 'name': 'Odyssey'},
#  {'id': 89, 'name': 'Microvision'},
#  {'id': 90, 'name': 'Commodore PET'},
#  {'id': 94, 'name': 'Commodore Plus/4'},
#  {'id': 150, 'name': 'Turbografx-16/PC Engine CD'},
#  {'id': 156, 'name': 'Thomson MO5'},
#  {'id': 158, 'name': 'Commodore CDTV'},
#  {'id': 163, 'name': 'SteamVR'},
#  {'id': 237, 'name': 'Sol-20'},
#  {'id': 378, 'name': 'Gamate'},
#  {'id': 381, 'name': 'Playdate'},
#  {'id': 477, 'name': 'Panasonic Jungle'},
#  {'id': 108, 'name': 'PDP-11'},
#  {'id': 109, 'name': 'CDC Cyber 70'},
#  {'id': 112, 'name': 'Microcomputer'},
#  {'id': 113, 'name': 'OnLive Game System'},
#  {'id': 115, 'name': 'Apple IIGS'},
#  {'id': 130, 'name': 'Nintendo Switch'},
#  {'id': 119, 'name': 'Neo Geo Pocket'},
#  {'id': 120, 'name': 'Neo Geo Pocket Color'},
#  {'id': 124, 'name': 'SwanCrystal'},
#  {'id': 125, 'name': 'PC-8800 Series'},
#  {'id': 126, 'name': 'TRS-80'},
#  {'id': 127, 'name': 'Fairchild Channel F'},
#  {'id': 132, 'name': 'Amazon Fire TV'},
#  {'id': 138, 'name': 'VC 4000'},
#  {'id': 139, 'name': '1292 Advanced Programmable Video System'},
#  {'id': 11, 'name': 'Xbox'},
#  {'id': 13, 'name': 'DOS'},
#  {'id': 24, 'name': 'Game Boy Advance'},
#  {'id': 30, 'name': 'Sega 32X'},
#  {'id': 41, 'name': 'Wii U'},
#  {'id': 53, 'name': 'MSX2'},
#  {'id': 60, 'name': 'Atari 7800'},
#  {'id': 70, 'name': 'Vectrex'},
#  {'id': 77, 'name': 'Sharp X1'},
#  {'id': 78, 'name': 'Sega CD'},
#  {'id': 85, 'name': 'Donner Model 30'},
#  {'id': 87, 'name': 'Virtual Boy'},
#  {'id': 97, 'name': 'PDP-8'},
#  {'id': 98, 'name': 'DEC GT40'},
#  {'id': 101, 'name': 'Ferranti Nimrod Computer'},
#  {'id': 140, 'name': 'AY-3-8500'},
#  {'id': 143, 'name': 'AY-3-8760'},
#  {'id': 145, 'name': 'AY-3-8603'},
#  {'id': 153, 'name': 'Dragon 32/64'},
#  {'id': 154, 'name': 'Amstrad PCW'},
#  {'id': 155, 'name': 'Tatung Einstein'},
#  {'id': 159, 'name': 'Nintendo DSi'},
#  {'id': 111, 'name': 'Imlac PDS-1'},
#  {'id': 114, 'name': 'Amiga CD32'},
#  {'id': 116, 'name': 'Acorn Archimedes'},
#  {'id': 117, 'name': 'Philips CD-i'},
#  {'id': 118, 'name': 'FM Towns'},
#  {'id': 121, 'name': 'Sharp X68000'},
#  {'id': 122, 'name': 'Nuon'},
#  {'id': 131, 'name': 'Nintendo PlayStation'},
#  {'id': 141, 'name': 'AY-3-8610'},
#  {'id': 152, 'name': 'FM-7'},
#  {'id': 157, 'name': 'NEC PC-6000 Series'},
#  {'id': 162, 'name': 'Oculus VR'},
#  {'id': 306, 'name': 'Satellaview'},
#  {'id': 9, 'name': 'PlayStation 3'},
#  {'id': 15, 'name': 'Commodore C64/128/MAX'},
#  {'id': 18, 'name': 'Nintendo Entertainment System'},
#  {'id': 20, 'name': 'Nintendo DS'},
#  {'id': 22, 'name': 'Game Boy Color'},
#  {'id': 32, 'name': 'Sega Saturn'},
#  {'id': 37, 'name': 'Nintendo 3DS'},
#  {'id': 38, 'name': 'PlayStation Portable'},
#  {'id': 46, 'name': 'PlayStation Vita'},
#  {'id': 61, 'name': 'Atari Lynx'},
#  {'id': 63, 'name': 'Atari ST/STE'},
#  {'id': 64, 'name': 'Sega Master System/Mark III'},
#  {'id': 66, 'name': 'Atari 5200'},
#  {'id': 67, 'name': 'Intellivision'},
#  {'id': 73, 'name': 'BlackBerry OS'},
#  {'id': 307, 'name': 'Game & Watch'},
#  {'id': 308, 'name': 'Playdia'},
#  {'id': 339, 'name': 'Sega Pico'},
#  {'id': 86, 'name': 'TurboGrafx-16/PC Engine'},
#  {'id': 137, 'name': 'New Nintendo 3DS'},
#  {'id': 161, 'name': 'Windows Mixed Reality'},
#  {'id': 167, 'name': 'PlayStation 5'},
#  {'id': 170, 'name': 'Google Stadia'},
#  {'id': 374, 'name': 'Sharp MZ-2200'},
#  {'id': 375, 'name': 'Epoch Cassette Vision'},
#  {'id': 376, 'name': 'Epoch Super Cassette Vision'},
#  {'id': 377, 'name': 'Plug & Play'},
#  {'id': 379, 'name': 'Game.com'},
#  {'id': 382, 'name': 'Intellivision Amico'},
#  {'id': 5, 'name': 'Wii'},
#  {'id': 21, 'name': 'Nintendo GameCube'},
#  {'id': 33, 'name': 'Game Boy'},
#  {'id': 42, 'name': 'N-Gage'},
#  {'id': 52, 'name': 'Arcade'},
#  {'id': 55, 'name': 'Legacy Mobile Device'},
#  {'id': 57, 'name': 'WonderSwan'},
#  {'id': 58, 'name': 'Super Famicom'},
#  {'id': 69, 'name': 'BBC Microcomputer System'},
#  {'id': 71, 'name': 'Commodore VIC-20'},
#  {'id': 74, 'name': 'Windows Phone'},
#  {'id': 79, 'name': 'Neo Geo MVS'},
#  {'id': 80, 'name': 'Neo Geo AES'},
#  {'id': 84, 'name': 'SG-1000'},
#  {'id': 91, 'name': 'Bally Astrocade'},
#  {'id': 93, 'name': 'Commodore 16'},
#  {'id': 96, 'name': 'PDP-10'},
#  {'id': 384, 'name': 'Oculus Quest'},
#  {'id': 385, 'name': 'Oculus Rift'},
#  {'id': 387, 'name': 'Oculus Go'},
#  {'id': 388, 'name': 'Gear VR'},
#  {'id': 479, 'name': "Terebikko / See 'n Say Video Phone"},
#  {'id': 103, 'name': 'PDP-7'},
#  {'id': 104, 'name': 'HP 2100'},
#  {'id': 106, 'name': 'SDS Sigma 7'},
#  {'id': 107, 'name': 'Call-A-Computer time-shared mainframe computer system'},
#  {'id': 105, 'name': 'HP 3000'},
#  {'id': 239, 'name': 'Blu-ray Player'},
#  {'id': 110, 'name': 'PLATO'},
#  {'id': 151, 'name': 'TRS-80 Color Computer'},
#  {'id': 164, 'name': 'Daydream'},
#  {'id': 26, 'name': 'ZX Spectrum'},
#  {'id': 27, 'name': 'MSX'},
#  {'id': 95, 'name': 'PDP-1'},
#  {'id': 100, 'name': 'Analogue electronics'},
#  {'id': 102, 'name': 'EDSAC'},
#  {'id': 166, 'name': 'Pokémon mini'},
#  {'id': 169, 'name': 'Xbox Series X|S'},
#  {'id': 203, 'name': 'DUPLICATE Stadia'},
#  {'id': 236, 'name': 'Exidy Sorcerer'},
#  {'id': 238, 'name': 'DVD Player'},
#  {'id': 240, 'name': 'Zeebo'},
#  {'id': 274, 'name': 'PC-FX'},
#  {'id': 309, 'name': 'Evercade'},
#  {'id': 372, 'name': 'OOParts'},
#  {'id': 373, 'name': 'Sinclair ZX81'},
#  {'id': 380, 'name': 'Casio Loopy'},
#  {'id': 478, 'name': 'Panasonic M2'},
#  {'id': 165, 'name': 'PlayStation VR'},
#  {'id': 386, 'name': 'Meta Quest 2'},
#  {'id': 389, 'name': 'AirConsole'},
#  {'id': 407, 'name': 'HyperScan'},
#  {'id': 406, 'name': 'Sinclair QL'},
#  {'id': 409, 'name': 'Legacy Computer'},
#  {'id': 408, 'name': 'Mega Duck/Cougar Boy'},
#  {'id': 410, 'name': 'Atari Jaguar CD'},
#  {'id': 411, 'name': 'Handheld Electronic LCD'},
#  {'id': 412, 'name': 'Leapster'},
#  {'id': 414, 'name': 'LeapTV'},
#  {'id': 413, 'name': 'Leapster Explorer/LeadPad Explorer'},
#  {'id': 415, 'name': 'Watara/QuickShot Supervision'},
#  {'id': 417, 'name': 'Palm OS'},
#  {'id': 416, 'name': 'Nintendo 64DD'},
#  {'id': 438, 'name': 'Arduboy'},
#  {'id': 439, 'name': 'V.Smile'},
#  {'id': 471, 'name': 'Meta Quest 3'},
#  {'id': 441, 'name': 'PocketStation'},
#  {'id': 480, 'name': "Super A'Can"},
#  {'id': 7, 'name': 'PlayStation'},
#  {'id': 16, 'name': 'Amiga'},
#  {'id': 29, 'name': 'Sega Mega Drive/Genesis'},
#  {'id': 47, 'name': 'Virtual Console'},
#  {'id': 49, 'name': 'Xbox One'},
#  {'id': 99, 'name': 'Family Computer'},
#  {'id': 390, 'name': 'PlayStation VR2'},
#  {'id': 405, 'name': 'Windows Mobile'},
#  {'id': 472, 'name': 'visionOS'},
#  {'id': 440, 'name': 'Visual Memory Unit / Visual Memory System'},
#  {'id': 473, 'name': 'Arcadia 2001'},
#  {'id': 474, 'name': 'Gizmondo'},
#  {'id': 475, 'name': 'R-Zone'},
#  {'id': 3, 'name': 'Linux'},
#  {'id': 4, 'name': 'Nintendo 64'},
#  {'id': 12, 'name': 'Xbox 360'},
#  {'id': 14, 'name': 'Mac'},
#  {'id': 19, 'name': 'Super Nintendo Entertainment System'},
#  {'id': 34, 'name': 'Android'},
#  {'id': 48, 'name': 'PlayStation 4'},
#  {'id': 51, 'name': 'Family Computer Disk System'},
#  {'id': 59, 'name': 'Atari 2600'},
#  {'id': 68, 'name': 'ColecoVision'},
#  {'id': 476, 'name': 'Apple Pippin'},
#  {'id': 481, 'name': 'Tomy Tutor / Pyuta / Grandstand Tutor'},
#  {'id': 72, 'name': 'Ouya'},
#  {'id': 75, 'name': 'Apple II'},
#  {'id': 82, 'name': 'Web browser'},
#  {'id': 11, 'name': 'Xbox'},
#  {'id': 13, 'name': 'DOS'},
#  {'id': 24, 'name': 'Game Boy Advance'},
#  {'id': 30, 'name': 'Sega 32X'},
#  {'id': 41, 'name': 'Wii U'},
#  {'id': 53, 'name': 'MSX2'},
#  {'id': 60, 'name': 'Atari 7800'},
#  {'id': 70, 'name': 'Vectrex'},
#  {'id': 77, 'name': 'Sharp X1'},
#  {'id': 78, 'name': 'Sega CD'},
#  {'id': 85, 'name': 'Donner Model 30'},
#  {'id': 87, 'name': 'Virtual Boy'},
#  {'id': 97, 'name': 'PDP-8'},
#  {'id': 98, 'name': 'DEC GT40'},
#  {'id': 101, 'name': 'Ferranti Nimrod Computer'},
#  {'id': 140, 'name': 'AY-3-8500'},
#  {'id': 143, 'name': 'AY-3-8760'},
#  {'id': 145, 'name': 'AY-3-8603'},
#  {'id': 153, 'name': 'Dragon 32/64'},
#  {'id': 154, 'name': 'Amstrad PCW'},
#  {'id': 155, 'name': 'Tatung Einstein'},
#  {'id': 159, 'name': 'Nintendo DSi'},
#  {'id': 111, 'name': 'Imlac PDS-1'},
#  {'id': 114, 'name': 'Amiga CD32'},
#  {'id': 116, 'name': 'Acorn Archimedes'},
#  {'id': 117, 'name': 'Philips CD-i'},
#  {'id': 118, 'name': 'FM Towns'},
#  {'id': 121, 'name': 'Sharp X68000'},
#  {'id': 122, 'name': 'Nuon'},
#  {'id': 131, 'name': 'Nintendo PlayStation'},
#  {'id': 141, 'name': 'AY-3-8610'},
#  {'id': 152, 'name': 'FM-7'},
#  {'id': 157, 'name': 'NEC PC-6000 Series'},
#  {'id': 162, 'name': 'Oculus VR'},
#  {'id': 306, 'name': 'Satellaview'},
#  {'id': 9, 'name': 'PlayStation 3'},
#  {'id': 15, 'name': 'Commodore C64/128/MAX'},
#  {'id': 18, 'name': 'Nintendo Entertainment System'},
#  {'id': 20, 'name': 'Nintendo DS'},
#  {'id': 22, 'name': 'Game Boy Color'},
#  {'id': 32, 'name': 'Sega Saturn'},
#  {'id': 37, 'name': 'Nintendo 3DS'},
#  {'id': 38, 'name': 'PlayStation Portable'},
#  {'id': 46, 'name': 'PlayStation Vita'},
#  {'id': 61, 'name': 'Atari Lynx'},
#  {'id': 63, 'name': 'Atari ST/STE'},
#  {'id': 64, 'name': 'Sega Master System/Mark III'},
#  {'id': 66, 'name': 'Atari 5200'},
#  {'id': 67, 'name': 'Intellivision'},
#  {'id': 73, 'name': 'BlackBerry OS'},
#  {'id': 307, 'name': 'Game & Watch'},
#  {'id': 308, 'name': 'Playdia'},
#  {'id': 339, 'name': 'Sega Pico'},
#  {'id': 86, 'name': 'TurboGrafx-16/PC Engine'},
#  {'id': 137, 'name': 'New Nintendo 3DS'},
#  {'id': 161, 'name': 'Windows Mixed Reality'},
#  {'id': 167, 'name': 'PlayStation 5'},
#  {'id': 170, 'name': 'Google Stadia'},
#  {'id': 374, 'name': 'Sharp MZ-2200'},
#  {'id': 375, 'name': 'Epoch Cassette Vision'},
#  {'id': 376, 'name': 'Epoch Super Cassette Vision'},
#  {'id': 377, 'name': 'Plug & Play'},
#  {'id': 379, 'name': 'Game.com'},
#  {'id': 382, 'name': 'Intellivision Amico'},
#  {'id': 5, 'name': 'Wii'},
#  {'id': 21, 'name': 'Nintendo GameCube'},
#  {'id': 33, 'name': 'Game Boy'},
#  {'id': 42, 'name': 'N-Gage'},
#  {'id': 52, 'name': 'Arcade'},
#  {'id': 55, 'name': 'Legacy Mobile Device'},
#  {'id': 57, 'name': 'WonderSwan'},
#  {'id': 58, 'name': 'Super Famicom'},
#  {'id': 69, 'name': 'BBC Microcomputer System'},
#  {'id': 71, 'name': 'Commodore VIC-20'},
#  {'id': 74, 'name': 'Windows Phone'},
#  {'id': 79, 'name': 'Neo Geo MVS'},
#  {'id': 80, 'name': 'Neo Geo AES'},
#  {'id': 84, 'name': 'SG-1000'},
#  {'id': 91, 'name': 'Bally Astrocade'},
#  {'id': 93, 'name': 'Commodore 16'},
#  {'id': 96, 'name': 'PDP-10'},
#  {'id': 384, 'name': 'Oculus Quest'},
#  {'id': 385, 'name': 'Oculus Rift'},
#  {'id': 387, 'name': 'Oculus Go'},
#  {'id': 388, 'name': 'Gear VR'},
#  {'id': 479, 'name': "Terebikko / See 'n Say Video Phone"},
#  {'id': 103, 'name': 'PDP-7'},
#  {'id': 104, 'name': 'HP 2100'},
#  {'id': 106, 'name': 'SDS Sigma 7'},
#  {'id': 107, 'name': 'Call-A-Computer time-shared mainframe computer system'},
#  {'id': 105, 'name': 'HP 3000'},
#  {'id': 239, 'name': 'Blu-ray Player'},
#  {'id': 110, 'name': 'PLATO'},
#  {'id': 151, 'name': 'TRS-80 Color Computer'},
#  {'id': 164, 'name': 'Daydream'},
#  {'id': 26, 'name': 'ZX Spectrum'},
#  {'id': 27, 'name': 'MSX'},
#  {'id': 95, 'name': 'PDP-1'},
#  {'id': 100, 'name': 'Analogue electronics'},
#  {'id': 102, 'name': 'EDSAC'},
#  {'id': 166, 'name': 'Pokémon mini'},
#  {'id': 169, 'name': 'Xbox Series X|S'},
#  {'id': 203, 'name': 'DUPLICATE Stadia'},
#  {'id': 236, 'name': 'Exidy Sorcerer'},
#  {'id': 238, 'name': 'DVD Player'},
#  {'id': 240, 'name': 'Zeebo'},
#  {'id': 274, 'name': 'PC-FX'},
#  {'id': 309, 'name': 'Evercade'},
#  {'id': 372, 'name': 'OOParts'},
#  {'id': 373, 'name': 'Sinclair ZX81'},
#  {'id': 380, 'name': 'Casio Loopy'},
#  {'id': 478, 'name': 'Panasonic M2'},
#  {'id': 165, 'name': 'PlayStation VR'},
#  {'id': 386, 'name': 'Meta Quest 2'},
#  {'id': 389, 'name': 'AirConsole'},
#  {'id': 407, 'name': 'HyperScan'},
#  {'id': 406, 'name': 'Sinclair QL'},
#  {'id': 409, 'name': 'Legacy Computer'},
#  {'id': 408, 'name': 'Mega Duck/Cougar Boy'},
#  {'id': 410, 'name': 'Atari Jaguar CD'},
#  {'id': 411, 'name': 'Handheld Electronic LCD'},
#  {'id': 412, 'name': 'Leapster'},
#  {'id': 414, 'name': 'LeapTV'},
#  {'id': 413, 'name': 'Leapster Explorer/LeadPad Explorer'},
#  {'id': 415, 'name': 'Watara/QuickShot Supervision'},
#  {'id': 417, 'name': 'Palm OS'},
#  {'id': 416, 'name': 'Nintendo 64DD'},
#  {'id': 438, 'name': 'Arduboy'},
#  {'id': 439, 'name': 'V.Smile'},
#  {'id': 471, 'name': 'Meta Quest 3'},
#  {'id': 441, 'name': 'PocketStation'},
#  {'id': 480, 'name': "Super A'Can"},
#  {'id': 7, 'name': 'PlayStation'},
#  {'id': 16, 'name': 'Amiga'},
#  {'id': 29, 'name': 'Sega Mega Drive/Genesis'},
#  {'id': 47, 'name': 'Virtual Console'},
#  {'id': 49, 'name': 'Xbox One'},
#  {'id': 99, 'name': 'Family Computer'},
#  {'id': 390, 'name': 'PlayStation VR2'},
#  {'id': 405, 'name': 'Windows Mobile'},
#  {'id': 472, 'name': 'visionOS'},
#  {'id': 440, 'name': 'Visual Memory Unit / Visual Memory System'},
#  {'id': 473, 'name': 'Arcadia 2001'},
#  {'id': 474, 'name': 'Gizmondo'},
#  {'id': 475, 'name': 'R-Zone'},
#  {'id': 3, 'name': 'Linux'},
#  {'id': 4, 'name': 'Nintendo 64'},
#  {'id': 12, 'name': 'Xbox 360'},
#  {'id': 14, 'name': 'Mac'},
#  {'id': 19, 'name': 'Super Nintendo Entertainment System'},
#  {'id': 34, 'name': 'Android'},
#  {'id': 48, 'name': 'PlayStation 4'},
#  {'id': 51, 'name': 'Family Computer Disk System'},
#  {'id': 59, 'name': 'Atari 2600'},
#  {'id': 68, 'name': 'ColecoVision'},
#  {'id': 476, 'name': 'Apple Pippin'},
#  {'id': 481, 'name': 'Tomy Tutor / Pyuta / Grandstand Tutor'},
#  {'id': 72, 'name': 'Ouya'},
#  {'id': 75, 'name': 'Apple II'},
#  {'id': 82, 'name': 'Web browser'},
#  {'id': 307, 'name': 'Game & Watch'},
#  {'id': 308, 'name': 'Playdia'},
#  {'id': 339, 'name': 'Sega Pico'},
#  {'id': 86, 'name': 'TurboGrafx-16/PC Engine'},
#  {'id': 137, 'name': 'New Nintendo 3DS'},
#  {'id': 161, 'name': 'Windows Mixed Reality'},
#  {'id': 167, 'name': 'PlayStation 5'},
#  {'id': 170, 'name': 'Google Stadia'},
#  {'id': 374, 'name': 'Sharp MZ-2200'},
#  {'id': 375, 'name': 'Epoch Cassette Vision'},
#  {'id': 376, 'name': 'Epoch Super Cassette Vision'},
#  {'id': 377, 'name': 'Plug & Play'},
#  {'id': 379, 'name': 'Game.com'},
#  {'id': 382, 'name': 'Intellivision Amico'},
#  {'id': 5, 'name': 'Wii'},
#  {'id': 21, 'name': 'Nintendo GameCube'},
#  {'id': 33, 'name': 'Game Boy'},
#  {'id': 42, 'name': 'N-Gage'},
#  {'id': 52, 'name': 'Arcade'},
#  {'id': 55, 'name': 'Legacy Mobile Device'},
#  {'id': 57, 'name': 'WonderSwan'},
#  {'id': 58, 'name': 'Super Famicom'},
#  {'id': 69, 'name': 'BBC Microcomputer System'},
#  {'id': 71, 'name': 'Commodore VIC-20'},
#  {'id': 74, 'name': 'Windows Phone'},
#  {'id': 79, 'name': 'Neo Geo MVS'},
#  {'id': 80, 'name': 'Neo Geo AES'},
#  {'id': 84, 'name': 'SG-1000'},
#  {'id': 91, 'name': 'Bally Astrocade'},
#  {'id': 93, 'name': 'Commodore 16'},
#  {'id': 96, 'name': 'PDP-10'},
#  {'id': 384, 'name': 'Oculus Quest'},
#  {'id': 385, 'name': 'Oculus Rift'},
#  {'id': 387, 'name': 'Oculus Go'},
#  {'id': 388, 'name': 'Gear VR'},
#  {'id': 479, 'name': "Terebikko / See 'n Say Video Phone"},
#  {'id': 103, 'name': 'PDP-7'},
#  {'id': 104, 'name': 'HP 2100'},
#  {'id': 106, 'name': 'SDS Sigma 7'},
#  {'id': 107, 'name': 'Call-A-Computer time-shared mainframe computer system'},
#  {'id': 105, 'name': 'HP 3000'},
#  {'id': 239, 'name': 'Blu-ray Player'},
#  {'id': 110, 'name': 'PLATO'},
#  {'id': 151, 'name': 'TRS-80 Color Computer'},
#  {'id': 164, 'name': 'Daydream'},
#  {'id': 26, 'name': 'ZX Spectrum'},
#  {'id': 27, 'name': 'MSX'},
#  {'id': 95, 'name': 'PDP-1'},
#  {'id': 100, 'name': 'Analogue electronics'},
#  {'id': 102, 'name': 'EDSAC'},
#  {'id': 166, 'name': 'Pokémon mini'},
#  {'id': 169, 'name': 'Xbox Series X|S'},
#  {'id': 203, 'name': 'DUPLICATE Stadia'},
#  {'id': 236, 'name': 'Exidy Sorcerer'},
#  {'id': 238, 'name': 'DVD Player'},
#  {'id': 240, 'name': 'Zeebo'},
#  {'id': 274, 'name': 'PC-FX'},
#  {'id': 309, 'name': 'Evercade'},
#  {'id': 372, 'name': 'OOParts'},
#  {'id': 373, 'name': 'Sinclair ZX81'},
#  {'id': 380, 'name': 'Casio Loopy'},
#  {'id': 478, 'name': 'Panasonic M2'},
#  {'id': 165, 'name': 'PlayStation VR'},
#  {'id': 386, 'name': 'Meta Quest 2'},
#  {'id': 389, 'name': 'AirConsole'},
#  {'id': 407, 'name': 'HyperScan'},
#  {'id': 406, 'name': 'Sinclair QL'},
#  {'id': 409, 'name': 'Legacy Computer'},
#  {'id': 408, 'name': 'Mega Duck/Cougar Boy'},
#  {'id': 410, 'name': 'Atari Jaguar CD'},
#  {'id': 411, 'name': 'Handheld Electronic LCD'},
#  {'id': 412, 'name': 'Leapster'},
#  {'id': 414, 'name': 'LeapTV'},
#  {'id': 413, 'name': 'Leapster Explorer/LeadPad Explorer'},
#  {'id': 415, 'name': 'Watara/QuickShot Supervision'},
#  {'id': 417, 'name': 'Palm OS'},
#  {'id': 416, 'name': 'Nintendo 64DD'},
#  {'id': 438, 'name': 'Arduboy'},
#  {'id': 439, 'name': 'V.Smile'},
#  {'id': 471, 'name': 'Meta Quest 3'},
#  {'id': 441, 'name': 'PocketStation'},
#  {'id': 480, 'name': "Super A'Can"},
#  {'id': 7, 'name': 'PlayStation'},
#  {'id': 16, 'name': 'Amiga'},
#  {'id': 29, 'name': 'Sega Mega Drive/Genesis'},
#  {'id': 47, 'name': 'Virtual Console'},
#  {'id': 49, 'name': 'Xbox One'},
#  {'id': 99, 'name': 'Family Computer'},
#  {'id': 390, 'name': 'PlayStation VR2'},
#  {'id': 405, 'name': 'Windows Mobile'},
#  {'id': 472, 'name': 'visionOS'},
#  {'id': 440, 'name': 'Visual Memory Unit / Visual Memory System'},
#  {'id': 473, 'name': 'Arcadia 2001'},
#  {'id': 474, 'name': 'Gizmondo'},
#  {'id': 475, 'name': 'R-Zone'},
#  {'id': 3, 'name': 'Linux'},
#  {'id': 4, 'name': 'Nintendo 64'},
#  {'id': 12, 'name': 'Xbox 360'},
#  {'id': 14, 'name': 'Mac'},
#  {'id': 19, 'name': 'Super Nintendo Entertainment System'},
#  {'id': 34, 'name': 'Android'},
#  {'id': 48, 'name': 'PlayStation 4'},
#  {'id': 51, 'name': 'Family Computer Disk System'},
#  {'id': 59, 'name': 'Atari 2600'},
#  {'id': 68, 'name': 'ColecoVision'},
#  {'id': 476, 'name': 'Apple Pippin'},
#  {'id': 481, 'name': 'Tomy Tutor / Pyuta / Grandstand Tutor'},
#  {'id': 72, 'name': 'Ouya'},
#  {'id': 75, 'name': 'Apple II'},
#  {'id': 82, 'name': 'Web browser'},
#  {'id': 166, 'name': 'Pokémon mini'},
#  {'id': 169, 'name': 'Xbox Series X|S'},
#  {'id': 203, 'name': 'DUPLICATE Stadia'},
#  {'id': 236, 'name': 'Exidy Sorcerer'},
#  {'id': 238, 'name': 'DVD Player'},
#  {'id': 240, 'name': 'Zeebo'},
#  {'id': 274, 'name': 'PC-FX'},
#  {'id': 309, 'name': 'Evercade'},
#  {'id': 372, 'name': 'OOParts'},
#  {'id': 373, 'name': 'Sinclair ZX81'},
#  {'id': 380, 'name': 'Casio Loopy'},
#  {'id': 478, 'name': 'Panasonic M2'},
#  {'id': 165, 'name': 'PlayStation VR'},
#  {'id': 386, 'name': 'Meta Quest 2'},
#  {'id': 389, 'name': 'AirConsole'},
#  {'id': 407, 'name': 'HyperScan'},
#  {'id': 406, 'name': 'Sinclair QL'},
#  {'id': 409, 'name': 'Legacy Computer'},
#  {'id': 408, 'name': 'Mega Duck/Cougar Boy'},
#  {'id': 410, 'name': 'Atari Jaguar CD'},
#  {'id': 411, 'name': 'Handheld Electronic LCD'},
#  {'id': 412, 'name': 'Leapster'},
#  {'id': 414, 'name': 'LeapTV'},
#  {'id': 413, 'name': 'Leapster Explorer/LeadPad Explorer'},
#  {'id': 415, 'name': 'Watara/QuickShot Supervision'},
#  {'id': 417, 'name': 'Palm OS'},
#  {'id': 416, 'name': 'Nintendo 64DD'},
#  {'id': 438, 'name': 'Arduboy'},
#  {'id': 439, 'name': 'V.Smile'},
#  {'id': 471, 'name': 'Meta Quest 3'},
#  {'id': 441, 'name': 'PocketStation'},
#  {'id': 480, 'name': "Super A'Can"},
#  {'id': 7, 'name': 'PlayStation'},
#  {'id': 16, 'name': 'Amiga'},
#  {'id': 29, 'name': 'Sega Mega Drive/Genesis'},
#  {'id': 47, 'name': 'Virtual Console'},
#  {'id': 49, 'name': 'Xbox One'},
#  {'id': 99, 'name': 'Family Computer'},
#  {'id': 390, 'name': 'PlayStation VR2'},
#  {'id': 405, 'name': 'Windows Mobile'},
#  {'id': 472, 'name': 'visionOS'},
#  {'id': 440, 'name': 'Visual Memory Unit / Visual Memory System'},
#  {'id': 473, 'name': 'Arcadia 2001'},
#  {'id': 474, 'name': 'Gizmondo'},
#  {'id': 475, 'name': 'R-Zone'},
#  {'id': 3, 'name': 'Linux'},
#  {'id': 4, 'name': 'Nintendo 64'},
#  {'id': 12, 'name': 'Xbox 360'},
#  {'id': 14, 'name': 'Mac'},
#  {'id': 19, 'name': 'Super Nintendo Entertainment System'},
#  {'id': 34, 'name': 'Android'},
#  {'id': 48, 'name': 'PlayStation 4'},
#  {'id': 51, 'name': 'Family Computer Disk System'},
#  {'id': 59, 'name': 'Atari 2600'},
#  {'id': 68, 'name': 'ColecoVision'},
#  {'id': 476, 'name': 'Apple Pippin'},
#  {'id': 481, 'name': 'Tomy Tutor / Pyuta / Grandstand Tutor'},
#  {'id': 72, 'name': 'Ouya'},
#  {'id': 75, 'name': 'Apple II'},
#  {'id': 82, 'name': 'Web browser'},
#  {'id': 34, 'name': 'Android'},
#  {'id': 48, 'name': 'PlayStation 4'},
#  {'id': 51, 'name': 'Family Computer Disk System'},
#  {'id': 59, 'name': 'Atari 2600'},
#  {'id': 68, 'name': 'ColecoVision'},
#  {'id': 476, 'name': 'Apple Pippin'},
#  {'id': 481, 'name': 'Tomy Tutor / Pyuta / Grandstand Tutor'},
#  {'id': 72, 'name': 'Ouya'},
#  {'id': 75, 'name': 'Apple II'},
#  {'id': 82, 'name': 'Web browser'}]

# %%
# for genres
url = "https://api.igdb.com/v4/genres"
all_genres = []
params = {
    "fields": "*",
    "limit": 500, 
    "offset": 0   
}
headers = {
    "Client-ID": client_id,
    "Authorization": f"Bearer {access_token}"
}

cap_genres = 10000000

while len(all_genres) < cap_genres:
    response = requests.get(url, headers=headers, params=params)
       
    if response.status_code == 200:
        genres_data = response.json()
        all_genres.extend(genres_data)
        
        if len(genres_data) < 50:
            break  
        else:
            params["offset"] += 50
    else:
        print("Failed to retrieve data:", response.status_code)
        break

all_genres = all_genres[:cap_genres]
genres_df = pd.DataFrame(all_genres)
genres_df = genres_df[['name', 'id']]

# %%
genres_response = []
for index, row in genres_df.iterrows():
    genre_dict = {'id': row['id'], 'name': row['name']}
    genres_response.append(genre_dict)

genres_response
# Out:
# [{'id': 2, 'name': 'Point-and-click'},
#  {'id': 4, 'name': 'Fighting'},
#  {'id': 5, 'name': 'Shooter'},
#  {'id': 7, 'name': 'Music'},
#  {'id': 8, 'name': 'Platform'},
#  {'id': 9, 'name': 'Puzzle'},
#  {'id': 10, 'name': 'Racing'},
#  {'id': 11, 'name': 'Real Time Strategy (RTS)'},
#  {'id': 12, 'name': 'Role-playing (RPG)'},
#  {'id': 13, 'name': 'Simulator'},
#  {'id': 14, 'name': 'Sport'},
#  {'id': 15, 'name': 'Strategy'},
#  {'id': 16, 'name': 'Turn-based strategy (TBS)'},
#  {'id': 24, 'name': 'Tactical'},
#  {'id': 25, 'name': "Hack and slash/Beat 'em up"},
#  {'id': 26, 'name': 'Quiz/Trivia'},
#  {'id': 30, 'name': 'Pinball'},
#  {'id': 31, 'name': 'Adventure'},
#  {'id': 32, 'name': 'Indie'},
#  {'id': 33, 'name': 'Arcade'},
#  {'id': 34, 'name': 'Visual Novel'},
#  {'id': 35, 'name': 'Card & Board Game'},
#  {'id': 36, 'name': 'MOBA'}]

# %%
# for game modes
url = "https://api.igdb.com/v4/game_modes"
all_game_modes = []
params = {
    "fields": "*",
    "limit": 500,  
    "offset": 0   
}
headers = {
    "Client-ID": client_id,
    "Authorization": f"Bearer {access_token}"
}


cap_game_modes = 10000000


while len(all_game_modes) < cap_game_modes:
    response = requests.get(url, headers=headers, params=params)
    
    if response.status_code == 200:
        game_modes_data = response.json()
        all_game_modes.extend(game_modes_data)
        
        if len(game_modes_data) < 50:
            break  
        else:
            params["offset"] += 50
    else:
        print("Failed to retrieve data:", response.status_code)
        break


all_game_modes = all_game_modes[:cap_game_modes]
game_modes_df = pd.DataFrame(all_game_modes)
game_modes_df = game_modes_df[['name', 'id']]

# %%
game_modes_response = []

for index, row in game_modes_df.iterrows():
    game_modes_dict = {'id': row['id'], 'name': row['name']}
    game_modes_response.append(game_modes_dict)

game_modes_response
# Out:
# [{'id': 1, 'name': 'Single player'},
#  {'id': 2, 'name': 'Multiplayer'},
#  {'id': 3, 'name': 'Co-operative'},
#  {'id': 4, 'name': 'Split screen'},
#  {'id': 5, 'name': 'Massively Multiplayer Online (MMO)'},
#  {'id': 6, 'name': 'Battle Royale'}]

# %%
import ast

df['genres'] = df['genres'].apply(ast.literal_eval) 
# type in df was object, so had to convert to list

genre_mapping = {genre['id']: genre['name'] for genre in genres_response} 
# creates relationship between id number and name

df['genres'] = df['genres'].apply(lambda x: [genre_mapping[genre_id] for genre_id in x]) 
# replaces numbers in the 'genres' column with genre names, applying to each list using lambda function
df
# Out:
# C:\Users\marcu\AppData\Local\Temp\ipykernel_27192\1845216971.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres'] = df['genres'].apply(ast.literal_eval)
# C:\Users\marcu\AppData\Local\Temp\ipykernel_27192\1845216971.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres'] = df['genres'].apply(lambda x: [genre_mapping[genre_id] for genre_id in x])
#                                     name  \
# 0                 Maji Kyun! Renaissance
# 1                        Soldier Front 2
# 2                   Bubble Whirl Shooter
# 3       Blood Bowl 3: Black Orcs Edition
# 4                             Pet Puzzle
# ...                                  ...
# 111590      .T.E.S.T: Expected Behaviour
# 111591                        Sol Cresta
# 111592                   Animal Hospital
# 111593        Alex Kidd in Miracle World
# 111594            Aliens: Fireteam Elite
#
#                                                   summary  \
# 0       A cross media collaboration project between Su...
# 1       A free-to-play multiplayer FPS currently in cl...
# 2       Shoot bubbles and match colors to pop your way...
# 3       Fashion is not exactly a priority for Black Or...
# 4       Pet Puzzle is a relaxing and leisurely three-i...
# ...                                                   ...
# 111590  .T.E.S.T: Expected Behavior is a 3D first-pers...
# 111591  DOCK, SPLIT, and FORM UP!\nPilot three ships a...
# 111592  Young animal lovers are warmly invited to come...
# 111593  Journey through the planet Aries to the beauti...
# 111594  Set in the iconic Alien universe, Aliens: Fire...
#
#                          platforms  \
# 0                             [46]
# 1                              [6]
# 2                         [34, 39]
# 3                        [49, 169]
# 4                              [6]
# ...                            ...
# 111590        [6, 14, 48, 49, 130]
# 111591                [6, 48, 130]
# 111592     [48, 49, 130, 167, 169]
# 111593                  [5, 9, 64]
# 111594  [6, 48, 49, 130, 167, 169]
#
#                                                    genres game_modes  \
# 0                                          [Visual Novel]        [1]
# 1                                               [Shooter]     [2, 3]
# 2                                        [Puzzle, Arcade]        [1]
# 3                                              [Strategy]     [1, 2]
# 4                                             [Simulator]        [1]
# ...                                                   ...        ...
# 111590              [Puzzle, Simulator, Adventure, Indie]        [1]
# 111591                [Shooter, Adventure, Indie, Arcade]        [1]
# 111592                                        [Simulator]        [1]
# 111593  [Platform, Hack and slash/Beat 'em up, Adventure]        [1]
# 111594           [Shooter, Role-playing (RPG), Adventure]  [1, 2, 3]
#
#                                                       url
# 0        https://www.igdb.com/games/maji-kyun-renaissance
# 1              https://www.igdb.com/games/soldier-front-2
# 2         https://www.igdb.com/games/bubble-whirl-shooter
# 3       https://www.igdb.com/games/blood-bowl-3-black-...
# 4                   https://www.igdb.com/games/pet-puzzle
# ...                                                   ...
# 111590  https://www.igdb.com/games/dot-t-e-dot-s-t-exp...
# 111591              https://www.igdb.com/games/sol-cresta
# 111592      https://www.igdb.com/games/animal-hospital--1
# 111593  https://www.igdb.com/games/alex-kidd-in-miracl...
# 111594   https://www.igdb.com/games/aliens-fireteam-elite
#
# [111595 rows x 6 columns]

# %%
df['platforms'] = df['platforms'].apply(ast.literal_eval)
platform_mapping = {platform['id']: platform['name'] for platform in platforms_response}
df['platforms'] = df['platforms'].apply(lambda x: [platform_mapping[platform_id] for platform_id in x])
df
# Out:
# C:\Users\marcu\AppData\Local\Temp\ipykernel_27192\2126513138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['platforms'] = df['platforms'].apply(ast.literal_eval)
# C:\Users\marcu\AppData\Local\Temp\ipykernel_27192\2126513138.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['platforms'] = df['platforms'].apply(lambda x: [platform_mapping[platform_id] for platform_id in x])
#                                     name  \
# 0                 Maji Kyun! Renaissance
# 1                        Soldier Front 2
# 2                   Bubble Whirl Shooter
# 3       Blood Bowl 3: Black Orcs Edition
# 4                             Pet Puzzle
# ...                                  ...
# 111590      .T.E.S.T: Expected Behaviour
# 111591                        Sol Cresta
# 111592                   Animal Hospital
# 111593        Alex Kidd in Miracle World
# 111594            Aliens: Fireteam Elite
#
#                                                   summary  \
# 0       A cross media collaboration project between Su...
# 1       A free-to-play multiplayer FPS currently in cl...
# 2       Shoot bubbles and match colors to pop your way...
# 3       Fashion is not exactly a priority for Black Or...
# 4       Pet Puzzle is a relaxing and leisurely three-i...
# ...                                                   ...
# 111590  .T.E.S.T: Expected Behavior is a 3D first-pers...
# 111591  DOCK, SPLIT, and FORM UP!\nPilot three ships a...
# 111592  Young animal lovers are warmly invited to come...
# 111593  Journey through the planet Aries to the beauti...
# 111594  Set in the iconic Alien universe, Aliens: Fire...
#
#                                                 platforms  \
# 0                                      [PlayStation Vita]
# 1                                [PC (Microsoft Windows)]
# 2                                          [Android, iOS]
# 3                             [Xbox One, Xbox Series X|S]
# 4                                [PC (Microsoft Windows)]
# ...                                                   ...
# 111590  [PC (Microsoft Windows), Mac, PlayStation 4, X...
# 111591  [PC (Microsoft Windows), PlayStation 4, Ninten...
# 111592  [PlayStation 4, Xbox One, Nintendo Switch, Pla...
# 111593  [Wii, PlayStation 3, Sega Master System/Mark III]
# 111594  [PC (Microsoft Windows), PlayStation 4, Xbox O...
#
#                                                    genres game_modes  \
# 0                                          [Visual Novel]        [1]
# 1                                               [Shooter]     [2, 3]
# 2                                        [Puzzle, Arcade]        [1]
# 3                                              [Strategy]     [1, 2]
# 4                                             [Simulator]        [1]
# ...                                                   ...        ...
# 111590              [Puzzle, Simulator, Adventure, Indie]        [1]
# 111591                [Shooter, Adventure, Indie, Arcade]        [1]
# 111592                                        [Simulator]        [1]
# 111593  [Platform, Hack and slash/Beat 'em up, Adventure]        [1]
# 111594           [Shooter, Role-playing (RPG), Adventure]  [1, 2, 3]
#
#                                                       url
# 0        https://www.igdb.com/games/maji-kyun-renaissance
# 1              https://www.igdb.com/games/soldier-front-2
# 2         https://www.igdb.com/games/bubble-whirl-shooter
# 3       https://www.igdb.com/games/blood-bowl-3-black-...
# 4                   https://www.igdb.com/games/pet-puzzle
# ...                                                   ...
# 111590  https://www.igdb.com/games/dot-t-e-dot-s-t-exp...
# 111591              https://www.igdb.com/games/sol-cresta
# 111592      https://www.igdb.com/games/animal-hospital--1
# 111593  https://www.igdb.com/games/alex-kidd-in-miracl...
# 111594   https://www.igdb.com/games/aliens-fireteam-elite
#
# [111595 rows x 6 columns]

# %%
df['game_modes'] = df['game_modes'].apply(ast.literal_eval)
game_mode_mapping = {mode['id']: mode['name'] for mode in game_modes_response}
df['game_modes'] = df['game_modes'].apply(lambda x: [game_mode_mapping[mode_id] for mode_id in x])
df
# Out:
# C:\Users\marcu\AppData\Local\Temp\ipykernel_27192\959824020.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['game_modes'] = df['game_modes'].apply(ast.literal_eval)
# C:\Users\marcu\AppData\Local\Temp\ipykernel_27192\959824020.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['game_modes'] = df['game_modes'].apply(lambda x: [game_mode_mapping[mode_id] for mode_id in x])
#                                     name  \
# 0                 Maji Kyun! Renaissance
# 1                        Soldier Front 2
# 2                   Bubble Whirl Shooter
# 3       Blood Bowl 3: Black Orcs Edition
# 4                             Pet Puzzle
# ...                                  ...
# 111590      .T.E.S.T: Expected Behaviour
# 111591                        Sol Cresta
# 111592                   Animal Hospital
# 111593        Alex Kidd in Miracle World
# 111594            Aliens: Fireteam Elite
#
#                                                   summary  \
# 0       A cross media collaboration project between Su...
# 1       A free-to-play multiplayer FPS currently in cl...
# 2       Shoot bubbles and match colors to pop your way...
# 3       Fashion is not exactly a priority for Black Or...
# 4       Pet Puzzle is a relaxing and leisurely three-i...
# ...                                                   ...
# 111590  .T.E.S.T: Expected Behavior is a 3D first-pers...
# 111591  DOCK, SPLIT, and FORM UP!\nPilot three ships a...
# 111592  Young animal lovers are warmly invited to come...
# 111593  Journey through the planet Aries to the beauti...
# 111594  Set in the iconic Alien universe, Aliens: Fire...
#
#                                                 platforms  \
# 0                                      [PlayStation Vita]
# 1                                [PC (Microsoft Windows)]
# 2                                          [Android, iOS]
# 3                             [Xbox One, Xbox Series X|S]
# 4                                [PC (Microsoft Windows)]
# ...                                                   ...
# 111590  [PC (Microsoft Windows), Mac, PlayStation 4, X...
# 111591  [PC (Microsoft Windows), PlayStation 4, Ninten...
# 111592  [PlayStation 4, Xbox One, Nintendo Switch, Pla...
# 111593  [Wii, PlayStation 3, Sega Master System/Mark III]
# 111594  [PC (Microsoft Windows), PlayStation 4, Xbox O...
#
#                                                    genres  \
# 0                                          [Visual Novel]
# 1                                               [Shooter]
# 2                                        [Puzzle, Arcade]
# 3                                              [Strategy]
# 4                                             [Simulator]
# ...                                                   ...
# 111590              [Puzzle, Simulator, Adventure, Indie]
# 111591                [Shooter, Adventure, Indie, Arcade]
# 111592                                        [Simulator]
# 111593  [Platform, Hack and slash/Beat 'em up, Adventure]
# 111594           [Shooter, Role-playing (RPG), Adventure]
#
#                                         game_modes  \
# 0                                  [Single player]
# 1                      [Multiplayer, Co-operative]
# 2                                  [Single player]
# 3                     [Single player, Multiplayer]
# 4                                  [Single player]
# ...                                            ...
# 111590                             [Single player]
# 111591                             [Single player]
# 111592                             [Single player]
# 111593                             [Single player]
# 111594  [Single player, Multiplayer, Co-operative]
#
#                                                       url
# 0        https://www.igdb.com/games/maji-kyun-renaissance
# 1              https://www.igdb.com/games/soldier-front-2
# 2         https://www.igdb.com/games/bubble-whirl-shooter
# 3       https://www.igdb.com/games/blood-bowl-3-black-...
# 4                   https://www.igdb.com/games/pet-puzzle
# ...                                                   ...
# 111590  https://www.igdb.com/games/dot-t-e-dot-s-t-exp...
# 111591              https://www.igdb.com/games/sol-cresta
# 111592      https://www.igdb.com/games/animal-hospital--1
# 111593  https://www.igdb.com/games/alex-kidd-in-miracl...
# 111594   https://www.igdb.com/games/aliens-fireteam-elite
#
# [111595 rows x 6 columns]

# %%
df['platforms'] = df['platforms'].apply(lambda x: ', '.join(x))
df['genres'] = df['genres'].apply(lambda x: ', '.join(x))
df['game_modes'] = df['game_modes'].apply(lambda x: ', '.join(x))
df
# Out:
# C:\Users\marcu\AppData\Local\Temp\ipykernel_27192\406184785.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['platforms'] = df['platforms'].apply(lambda x: ', '.join(x))
# C:\Users\marcu\AppData\Local\Temp\ipykernel_27192\406184785.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres'] = df['genres'].apply(lambda x: ', '.join(x))
# C:\Users\marcu\AppData\Local\Temp\ipykernel_27192\406184785.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['game_modes'] = df['game_modes'].apply(lambda x: ', '.join(x))
#                                     name  \
# 0                 Maji Kyun! Renaissance
# 1                        Soldier Front 2
# 2                   Bubble Whirl Shooter
# 3       Blood Bowl 3: Black Orcs Edition
# 4                             Pet Puzzle
# ...                                  ...
# 111590      .T.E.S.T: Expected Behaviour
# 111591                        Sol Cresta
# 111592                   Animal Hospital
# 111593        Alex Kidd in Miracle World
# 111594            Aliens: Fireteam Elite
#
#                                                   summary  \
# 0       A cross media collaboration project between Su...
# 1       A free-to-play multiplayer FPS currently in cl...
# 2       Shoot bubbles and match colors to pop your way...
# 3       Fashion is not exactly a priority for Black Or...
# 4       Pet Puzzle is a relaxing and leisurely three-i...
# ...                                                   ...
# 111590  .T.E.S.T: Expected Behavior is a 3D first-pers...
# 111591  DOCK, SPLIT, and FORM UP!\nPilot three ships a...
# 111592  Young animal lovers are warmly invited to come...
# 111593  Journey through the planet Aries to the beauti...
# 111594  Set in the iconic Alien universe, Aliens: Fire...
#
#                                                 platforms  \
# 0                                        PlayStation Vita
# 1                                  PC (Microsoft Windows)
# 2                                            Android, iOS
# 3                               Xbox One, Xbox Series X|S
# 4                                  PC (Microsoft Windows)
# ...                                                   ...
# 111590  PC (Microsoft Windows), Mac, PlayStation 4, Xb...
# 111591  PC (Microsoft Windows), PlayStation 4, Nintend...
# 111592  PlayStation 4, Xbox One, Nintendo Switch, Play...
# 111593    Wii, PlayStation 3, Sega Master System/Mark III
# 111594  PC (Microsoft Windows), PlayStation 4, Xbox On...
#
#                                                  genres  \
# 0                                          Visual Novel
# 1                                               Shooter
# 2                                        Puzzle, Arcade
# 3                                              Strategy
# 4                                             Simulator
# ...                                                 ...
# 111590              Puzzle, Simulator, Adventure, Indie
# 111591                Shooter, Adventure, Indie, Arcade
# 111592                                        Simulator
# 111593  Platform, Hack and slash/Beat 'em up, Adventure
# 111594           Shooter, Role-playing (RPG), Adventure
#
#                                       game_modes  \
# 0                                  Single player
# 1                      Multiplayer, Co-operative
# 2                                  Single player
# 3                     Single player, Multiplayer
# 4                                  Single player
# ...                                          ...
# 111590                             Single player
# 111591                             Single player
# 111592                             Single player
# 111593                             Single player
# 111594  Single player, Multiplayer, Co-operative
#
#                                                       url
# 0        https://www.igdb.com/games/maji-kyun-renaissance
# 1              https://www.igdb.com/games/soldier-front-2
# 2         https://www.igdb.com/games/bubble-whirl-shooter
# 3       https://www.igdb.com/games/blood-bowl-3-black-...
# 4                   https://www.igdb.com/games/pet-puzzle
# ...                                                   ...
# 111590  https://www.igdb.com/games/dot-t-e-dot-s-t-exp...
# 111591              https://www.igdb.com/games/sol-cresta
# 111592      https://www.igdb.com/games/animal-hospital--1
# 111593  https://www.igdb.com/games/alex-kidd-in-miracl...
# 111594   https://www.igdb.com/games/aliens-fireteam-elite
#
# [111595 rows x 6 columns]

# %% [markdown]
# Finally, there were some big name games in the data that had their own rows for their own season. Dropping the rows really had an impacting on the recommendations, so I could not do that. I had to change the names of these rows to the names of the original game. I also changed the link, so that if it is recommended, they will be directed to the main game as well.

# %%
result = df[df['name'].str.contains('Rocket League')]
df.loc[result.index, 'name'] = result['name'].str.split(':').str[0]
df.loc[result.index, 'url'] = 'https://www.igdb.com/games/rocket-league'
df[df['name'] == 'Rocket League']
# Out:
#                  name                                            summary  \
# 3003    Rocket League  Season 5 is the nineteenth competitive season ...
# 7158    Rocket League  Welcome, esteemed Rocketeers! Season 7 feature...
# 7757    Rocket League  Season 4 is the eighteenth competitive season ...
# 18688   Rocket League  It's time to take it outside!\nFar from the br...
# 42355   Rocket League  Rocket League equips players with booster-rigg...
# 47522   Rocket League  Welcome to the animated world of Rocket League...
# 49800   Rocket League  Rocket League is a high-powered hybrid of arca...
# 56885   Rocket League  Turn it up! Rocket League Season 2 is ready to...
# 59312   Rocket League  Expand your Rocket League customization option...
# 75201   Rocket League  The Season 1 Series include more than a dozen ...
# 75638   Rocket League  Soccer meets driving once again in the long-aw...
# 78258   Rocket League  Rocket League is futuristic Sports-Action game...
# 92914   Rocket League  Perched high above the seaside, a group of dri...
# 93331   Rocket League  Tape your Season highlights on VHS.\nThe 90s a...
# 94819   Rocket League  Long held in place by an ancient seal, the dra...
# 94908   Rocket League  Expand your Rocket League customization option...
# 95374   Rocket League  Rocket League Game of the Year Edition is a di...
# 95840   Rocket League  It's time to unwind\n\nLost long ago in the sh...
# 100556  Rocket League  DIVE INTO A FRESH AQUADOME ARENA IN ROCKET LEA...
# 103890  Rocket League  Start your engines! Rocket League Season 3 is ...
# 104066  Rocket League  Home to Rocket League’s opening day, Neo Tokyo...
#
#                                                 platforms  \
# 3003    Linux, PC (Microsoft Windows), Mac, PlayStatio...
# 7158    Linux, PC (Microsoft Windows), Mac, PlayStatio...
# 7757    Linux, PC (Microsoft Windows), Mac, PlayStatio...
# 18688   Linux, PC (Microsoft Windows), Mac, PlayStatio...
# 42355            PlayStation 4, Xbox One, Nintendo Switch
# 47522   Linux, PC (Microsoft Windows), Mac, PlayStatio...
# 49800   Linux, PC (Microsoft Windows), Mac, PlayStatio...
# 56885   Linux, PC (Microsoft Windows), Mac, PlayStatio...
# 59312   Linux, PC (Microsoft Windows), Mac, PlayStation 4
# 75201   Linux, PC (Microsoft Windows), Mac, PlayStatio...
# 75638   Linux, PC (Microsoft Windows), Mac, PlayStation 4
# 78258   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 92914   Linux, PC (Microsoft Windows), Mac, PlayStatio...
# 93331   Linux, PC (Microsoft Windows), Mac, PlayStatio...
# 94819   Linux, PC (Microsoft Windows), Mac, PlayStatio...
# 94908   Linux, PC (Microsoft Windows), Mac, PlayStation 4
# 95374               PC (Microsoft Windows), PlayStation 4
# 95840   Linux, PC (Microsoft Windows), Mac, PlayStatio...
# 100556  Linux, PC (Microsoft Windows), Mac, PlayStatio...
# 103890  Linux, PC (Microsoft Windows), Mac, PlayStatio...
# 104066  Linux, PC (Microsoft Windows), Mac, PlayStatio...
#
#                       genres  \
# 3003    Racing, Sport, Indie
# 7158    Racing, Sport, Indie
# 7757    Racing, Sport, Indie
# 18688   Racing, Sport, Indie
# 42355           Sport, Indie
# 47522   Racing, Sport, Indie
# 49800   Racing, Sport, Indie
# 56885   Racing, Sport, Indie
# 59312   Racing, Sport, Indie
# 75201   Racing, Sport, Indie
# 75638   Racing, Sport, Indie
# 78258           Sport, Indie
# 92914   Racing, Sport, Indie
# 93331   Racing, Sport, Indie
# 94819   Racing, Sport, Indie
# 94908   Racing, Sport, Indie
# 95374   Racing, Sport, Indie
# 95840   Racing, Sport, Indie
# 100556  Racing, Sport, Indie
# 103890  Racing, Sport, Indie
# 104066  Racing, Sport, Indie
#
#                                                game_modes  \
# 3003    Single player, Multiplayer, Co-operative, Spli...
# 7158    Single player, Multiplayer, Co-operative, Spli...
# 7757    Single player, Multiplayer, Co-operative, Spli...
# 18688   Single player, Multiplayer, Co-operative, Spli...
# 42355   Single player, Multiplayer, Co-operative, Spli...
# 47522   Single player, Multiplayer, Co-operative, Spli...
# 49800   Single player, Multiplayer, Co-operative, Spli...
# 56885   Single player, Multiplayer, Co-operative, Spli...
# 59312   Single player, Multiplayer, Co-operative, Spli...
# 75201   Single player, Multiplayer, Co-operative, Spli...
# 75638   Single player, Multiplayer, Co-operative, Spli...
# 78258   Single player, Multiplayer, Co-operative, Spli...
# 92914   Single player, Multiplayer, Co-operative, Spli...
# 93331   Single player, Multiplayer, Co-operative, Spli...
# 94819   Single player, Multiplayer, Co-operative, Spli...
# 94908   Single player, Multiplayer, Co-operative, Spli...
# 95374   Single player, Multiplayer, Co-operative, Spli...
# 95840   Single player, Multiplayer, Co-operative, Spli...
# 100556  Single player, Multiplayer, Co-operative, Spli...
# 103890  Single player, Multiplayer, Co-operative, Spli...
# 104066  Single player, Multiplayer, Co-operative, Spli...
#
#                                              url
# 3003    https://www.igdb.com/games/rocket-league
# 7158    https://www.igdb.com/games/rocket-league
# 7757    https://www.igdb.com/games/rocket-league
# 18688   https://www.igdb.com/games/rocket-league
# 42355   https://www.igdb.com/games/rocket-league
# 47522   https://www.igdb.com/games/rocket-league
# 49800   https://www.igdb.com/games/rocket-league
# 56885   https://www.igdb.com/games/rocket-league
# 59312   https://www.igdb.com/games/rocket-league
# 75201   https://www.igdb.com/games/rocket-league
# 75638   https://www.igdb.com/games/rocket-league
# 78258   https://www.igdb.com/games/rocket-league
# 92914   https://www.igdb.com/games/rocket-league
# 93331   https://www.igdb.com/games/rocket-league
# 94819   https://www.igdb.com/games/rocket-league
# 94908   https://www.igdb.com/games/rocket-league
# 95374   https://www.igdb.com/games/rocket-league
# 95840   https://www.igdb.com/games/rocket-league
# 100556  https://www.igdb.com/games/rocket-league
# 103890  https://www.igdb.com/games/rocket-league
# 104066  https://www.igdb.com/games/rocket-league

# %%
result1 = df[df['name'].str.contains('Fortnite')]
df.loc[result1.index, 'name'] = result1['name'].str.split(':').str[0]
df.loc[result1.index, 'url'] = 'https://www.igdb.com/games/fortnite'
df[df['name'] == 'Fortnite']
# Out:
#             name                                            summary  \
# 3023    Fortnite  Chapter 2: Season 8, is the eighteenth season ...
# 6427    Fortnite  Explore the Fortilla and build your own umbrel...
# 7681    Fortnite  Become everyone’s nemesis with The Last Laugh ...
# 8594    Fortnite  The volcano has erupted and forever changed so...
# 9797    Fortnite  Season 8 has arrived and a monstrous volcano h...
# 11897   Fortnite  Are you daring enough to enter the Wailing Woo...
# 11937   Fortnite  Chapter 2: Season 7, is the seventeenth season...
# 12370   Fortnite  Drop into Season 5, where we’re introducing al...
# 12784   Fortnite  Season 4 is starting off with a BANG. Shards o...
# 20844   Fortnite  Find out what Fortnite Wilds is all about when...
# 31380   Fortnite  Pandora’s Box has been opened on the Fortnite ...
# 53528   Fortnite  Fortnite is the completely free online game wh...
# 58054   Fortnite  In Fortnite Chapter 3 Season 4: Paradise, a my...
# 58698   Fortnite  The Fortnite: Deep Freeze Bundle will include ...
# 60769   Fortnite  Better than ever. More choices. New bonuses. 1...
# 60926   Fortnite  Season 7 has arrived with the smash of a myste...
# 63448   Fortnite  A season of Fortnite: Chapter 4\n\nThe fate of...
# 64006   Fortnite  A new beginning awaits.\n\nIn the fourth Chapt...
# 65879   Fortnite  Season 1 was the first iteration of player pro...
# 71339   Fortnite  Chapter 2: Season 6, is the sixteenth season i...
# 72290   Fortnite  Drop into a new world. Choose your landing spo...
# 75392   Fortnite  Board the helicarrier. Awaken the hero or vill...
# 80432   Fortnite  Drop in the original Island once again in Fort...
# 86242   Fortnite  Season 2 was focused on heraldic imagery: the ...
# 86301   Fortnite  The storyline began around this season with pl...
# 86335   Fortnite  The island from Chapter 2 has been turned upsi...
# 86434   Fortnite  The IO has lined up guards and sky stations, b...
# 89757   Fortnite  A new Season also means the debut of the Seaso...
# 96634   Fortnite  In Chapter 3 Season 3: Vibin’, the Island is o...
# 97963   Fortnite  Catch the train, customize your weapon, and cl...
# 98503   Fortnite  Become Mega in Fortnite Battle Royale: Chapter...
# 108247  Fortnite  Chapter 2: Season 5, also known as Season 15, ...
#
#                                                 platforms  \
# 3023    PC (Microsoft Windows), PlayStation 4, Xbox On...
# 6427      PC (Microsoft Windows), PlayStation 4, Xbox One
# 7681    PC (Microsoft Windows), PlayStation 4, Xbox On...
# 8594      PC (Microsoft Windows), PlayStation 4, Xbox One
# 9797      PC (Microsoft Windows), PlayStation 4, Xbox One
# 11897   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 11937   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 12370   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 12784   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 20844   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 31380   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 53528   PC (Microsoft Windows), Mac, Android, iOS, Pla...
# 58054   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 58698   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 60769     PC (Microsoft Windows), PlayStation 4, Xbox One
# 60926   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 63448   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 64006   PC (Microsoft Windows), Android, iOS, PlayStat...
# 65879     PC (Microsoft Windows), PlayStation 4, Xbox One
# 71339   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 72290     PC (Microsoft Windows), PlayStation 4, Xbox One
# 75392     PC (Microsoft Windows), PlayStation 4, Xbox One
# 80432   PC (Microsoft Windows), Android, PlayStation 4...
# 86242     PC (Microsoft Windows), PlayStation 4, Xbox One
# 86301     PC (Microsoft Windows), PlayStation 4, Xbox One
# 86335   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 86434   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 89757     PC (Microsoft Windows), PlayStation 4, Xbox One
# 96634   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 97963   PC (Microsoft Windows), PlayStation 4, Xbox On...
# 98503   PC (Microsoft Windows), PlayStation 4, Nintend...
# 108247  PC (Microsoft Windows), Mac, Android, iOS, Pla...
#
#                                                    genres  \
# 3023                Shooter, Role-playing (RPG), Strategy
# 6427                                              Shooter
# 7681                                              Shooter
# 8594                                              Shooter
# 9797                                              Shooter
# 11897                                             Shooter
# 11937                                             Shooter
# 12370                                             Shooter
# 12784                                             Shooter
# 20844                                             Shooter
# 31380                                   Shooter, Tactical
# 53528   Shooter, Role-playing (RPG), Simulator, Strate...
# 58054               Shooter, Role-playing (RPG), Strategy
# 58698   Shooter, Role-playing (RPG), Simulator, Sport,...
# 60769                                             Shooter
# 60926                                             Shooter
# 63448                                             Shooter
# 64006               Shooter, Role-playing (RPG), Strategy
# 65879                                             Shooter
# 71339                                             Shooter
# 72290                                             Shooter
# 75392                                             Shooter
# 80432               Shooter, Role-playing (RPG), Strategy
# 86242                                             Shooter
# 86301                                             Shooter
# 86335               Shooter, Role-playing (RPG), Strategy
# 86434               Shooter, Role-playing (RPG), Strategy
# 89757                                             Shooter
# 96634                                             Shooter
# 97963                                   Shooter, Tactical
# 98503                                             Shooter
# 108247                                            Shooter
#
#                                                game_modes  \
# 3023             Multiplayer, Co-operative, Battle Royale
# 6427    Single player, Multiplayer, Co-operative, Spli...
# 7681                           Single player, Multiplayer
# 8594    Single player, Multiplayer, Co-operative, Spli...
# 9797    Single player, Multiplayer, Co-operative, Spli...
# 11897   Single player, Multiplayer, Co-operative, Spli...
# 11937            Multiplayer, Co-operative, Battle Royale
# 12370   Single player, Multiplayer, Co-operative, Spli...
# 12784   Single player, Multiplayer, Co-operative, Spli...
# 20844                                       Battle Royale
# 31380                                       Battle Royale
# 53528   Single player, Multiplayer, Co-operative, Spli...
# 58054          Single player, Co-operative, Battle Royale
# 58698   Single player, Multiplayer, Co-operative, Batt...
# 60769   Single player, Multiplayer, Co-operative, Spli...
# 60926   Single player, Multiplayer, Co-operative, Spli...
# 63448                          Multiplayer, Battle Royale
# 64006            Multiplayer, Co-operative, Battle Royale
# 65879   Single player, Multiplayer, Co-operative, Spli...
# 71339            Multiplayer, Co-operative, Battle Royale
# 72290   Single player, Multiplayer, Co-operative, Spli...
# 75392   Single player, Multiplayer, Co-operative, Spli...
# 80432            Multiplayer, Co-operative, Battle Royale
# 86242   Single player, Multiplayer, Co-operative, Spli...
# 86301   Single player, Multiplayer, Co-operative, Spli...
# 86335            Multiplayer, Co-operative, Battle Royale
# 86434          Single player, Co-operative, Battle Royale
# 89757   Single player, Multiplayer, Co-operative, Spli...
# 96634                          Multiplayer, Battle Royale
# 97963                                         Multiplayer
# 98503                          Multiplayer, Battle Royale
# 108247           Multiplayer, Co-operative, Battle Royale
#
#                                         url
# 3023    https://www.igdb.com/games/fortnite
# 6427    https://www.igdb.com/games/fortnite
# 7681    https://www.igdb.com/games/fortnite
# 8594    https://www.igdb.com/games/fortnite
# 9797    https://www.igdb.com/games/fortnite
# 11897   https://www.igdb.com/games/fortnite
# 11937   https://www.igdb.com/games/fortnite
# 12370   https://www.igdb.com/games/fortnite
# 12784   https://www.igdb.com/games/fortnite
# 20844   https://www.igdb.com/games/fortnite
# 31380   https://www.igdb.com/games/fortnite
# 53528   https://www.igdb.com/games/fortnite
# 58054   https://www.igdb.com/games/fortnite
# 58698   https://www.igdb.com/games/fortnite
# 60769   https://www.igdb.com/games/fortnite
# 60926   https://www.igdb.com/games/fortnite
# 63448   https://www.igdb.com/games/fortnite
# 64006   https://www.igdb.com/games/fortnite
# 65879   https://www.igdb.com/games/fortnite
# 71339   https://www.igdb.com/games/fortnite
# 72290   https://www.igdb.com/games/fortnite
# 75392   https://www.igdb.com/games/fortnite
# 80432   https://www.igdb.com/games/fortnite
# 86242   https://www.igdb.com/games/fortnite
# 86301   https://www.igdb.com/games/fortnite
# 86335   https://www.igdb.com/games/fortnite
# 86434   https://www.igdb.com/games/fortnite
# 89757   https://www.igdb.com/games/fortnite
# 96634   https://www.igdb.com/games/fortnite
# 97963   https://www.igdb.com/games/fortnite
# 98503   https://www.igdb.com/games/fortnite
# 108247  https://www.igdb.com/games/fortnite

# %%
result2 = df[df['name'].str.contains('Overwatch 2')]
df.loc[result2.index, 'name'] = result2['name'].str.split(':').str[0]
df.loc[result2.index, 'url'] = 'https://www.igdb.com/games/overwatch-2'
df[df['name'] == 'Overwatch 2']
# Out:
#               name                                            summary  \
# 13093  Overwatch 2  Overwatch 2 Season 9: Champions launches Feb 1...
# 17384  Overwatch 2  Overwatch 2 Season 8: Call of the Hunt adds th...
# 17386  Overwatch 2  Embark on a mythic adventure!\n\nJoin Tracer a...
# 17429  Overwatch 2  Overwatch 2’s first tempo tank Ramattra joins ...
# 17463  Overwatch 2  Get ready for the spookiest event of the year,...
# 20791  Overwatch 2  Blossom onto the battlefield with our newest S...
# 27797  Overwatch 2  Drop into season three to explore the depths o...
# 30161  Overwatch 2  Overwatch 2 is a free-to-play shooter featurin...
# 30223  Overwatch 2  A totally real, totally non-canon dating sim h...
# 65376  Overwatch 2  Introducing Overwatch 2: Invasion, an all-new ...
# 85263  Overwatch 2  New heroes join the fight and all-new rewards ...
#
#                                                platforms  \
# 13093  PC (Microsoft Windows), PlayStation 4, Xbox On...
# 17384  PC (Microsoft Windows), PlayStation 4, Xbox On...
# 17386  PC (Microsoft Windows), PlayStation 4, Xbox On...
# 17429  PC (Microsoft Windows), PlayStation 4, Xbox On...
# 17463  PC (Microsoft Windows), PlayStation 4, Xbox On...
# 20791  PC (Microsoft Windows), PlayStation 4, Xbox On...
# 27797  PC (Microsoft Windows), PlayStation 4, Xbox On...
# 30161  PC (Microsoft Windows), PlayStation 4, Xbox On...
# 30223                                        Web browser
# 65376  PC (Microsoft Windows), PlayStation 4, Xbox On...
# 85263  PC (Microsoft Windows), PlayStation 4, Xbox On...
#
#                         genres                                game_modes  \
# 13093        Shooter, Strategy                               Multiplayer
# 17384                  Shooter                               Multiplayer
# 17386        Shooter, Strategy                               Multiplayer
# 17429        Shooter, Strategy  Single player, Multiplayer, Co-operative
# 17463                  Shooter                               Multiplayer
# 20791        Shooter, Strategy                Single player, Multiplayer
# 27797                  Shooter  Single player, Multiplayer, Co-operative
# 30161                  Shooter                 Multiplayer, Co-operative
# 30223  Simulator, Visual Novel                             Single player
# 65376        Shooter, Strategy                               Multiplayer
# 85263        Shooter, Strategy  Single player, Multiplayer, Co-operative
#
#                                           url
# 13093  https://www.igdb.com/games/overwatch-2
# 17384  https://www.igdb.com/games/overwatch-2
# 17386  https://www.igdb.com/games/overwatch-2
# 17429  https://www.igdb.com/games/overwatch-2
# 17463  https://www.igdb.com/games/overwatch-2
# 20791  https://www.igdb.com/games/overwatch-2
# 27797  https://www.igdb.com/games/overwatch-2
# 30161  https://www.igdb.com/games/overwatch-2
# 30223  https://www.igdb.com/games/overwatch-2
# 65376  https://www.igdb.com/games/overwatch-2
# 85263  https://www.igdb.com/games/overwatch-2

# %%
df.to_csv('games_clean.csv', index=False)
